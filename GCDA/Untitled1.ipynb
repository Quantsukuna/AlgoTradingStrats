# %%
import pandas as pd
import numpy as np
# !pip install plotly.express

# %%
data = pd.read_csv('Train_data.csv')

data.head()
# Out:
#   Warehouse id Region SKU id  Apr-18  May-18  Jun-18  Jul-18  Aug-18  Sep-18  \
# 0         Wh-1  NORTH  SKU-1      27      13      30      14      22       8
# 1         Wh-1  NORTH  SKU-2      88      28     127     130      58      10
# 2         Wh-1  NORTH  SKU-3       6       6       6       6       6       6
# 3         Wh-1  NORTH  SKU-4     162     184     110     172      90      40
# 4         Wh-1  NORTH  SKU-5     171     402     627     615     300     417
#
#    Oct-18  ...  Aug-20  Sep-20  Oct-20  Nov-20  Dec-20  Jan-21  Feb-21  \
# 0       8  ...      12       8       8       8       8       8      14
# 1       7  ...      16       7       7       7       7       7      13
# 2       6  ...       8       6       6       6       6       6       6
# 3      18  ...      82      78      38      18      22      28      36
# 4     141  ...     468     216      75       6      30      66     141
#
#    Mar-21  Apr-21  May-21
# 0      16       8      12
# ...

# %%
data.T
# Out:
#                0      1      2      3      4      5      6      7      8     \
# Warehouse id   Wh-1   Wh-1   Wh-1   Wh-1   Wh-1   Wh-1   Wh-1   Wh-1   Wh-1
# Region        NORTH  NORTH  NORTH  NORTH  NORTH  NORTH  NORTH  NORTH  NORTH
# SKU id        SKU-1  SKU-2  SKU-3  SKU-4  SKU-5  SKU-6  SKU-7  SKU-8  SKU-9
# Apr-18           27     88      6    162    171      4   1179    406    264
# May-18           13     28      6    184    402      4    435    652    244
# Jun-18           30    127      6    110    627      4    335    844    159
# Jul-18           14    130      6    172    615     52    719    541    204
# Aug-18           22     58      6     90    300      4    791    703     84
# Sep-18            8     10      6     40    417     12    783    634    129
# Oct-18            8      7      6     18    141      4    875    523    248
# Nov-18            8      7      6     26     42      4    935    688    166
# ...
